# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath('../scripts'))
from analysis_functions import analyze_headline_length,count_articles_per_publisher,analyze_publication_dates


df = pd.read_csv('../data/raw_analyst_ratings.csv')

# %% [markdown]
# Descriptive Statistics for Textual Lengths

# %%
print(analyze_headline_length(df))
# Out:
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64

# %% [markdown]
# Counting the Number of Articles per Publisher

# %%
print(count_articles_per_publisher(df))
# Out:
# publisher
# Paul Quintaro                      228373
# Lisa Levin                         186979
# Benzinga Newsdesk                  150484
# Charles Gross                       96732
# Monica Gerson                       82380
#                                     ...
# Shazir Mucklai - Imperium Group         1
# Laura Jennings                          1
# Eric Martin                             1
# Jose Rodrigo                            1
# Jeremie Capron                          1
# Name: count, Length: 1034, dtype: int64

# %% [markdown]
# Analyzing Publication Dates for Trends

# %%
analyze_publication_dates(df)
# Out:
# date
# 2011-04-27 00:00:00-04:00      1
# 2011-04-28 00:00:00-04:00      2
# 2011-04-29 00:00:00-04:00      2
# 2011-04-30 00:00:00-04:00      1
# 2011-05-01 00:00:00-04:00      1
#                             ...
# 2020-06-07 00:00:00-04:00     25
# 2020-06-08 00:00:00-04:00    765
# 2020-06-09 00:00:00-04:00    804
# 2020-06-10 00:00:00-04:00    806
# 2020-06-11 00:00:00-04:00    544
# Freq: D, Length: 3334, dtype: int64

# %%
df_with_sentiment = analyze_headlines_sentiment_advanced(df)

# Display the results
print(df_with_sentiment[['headline', 'sentiment']].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_with_sentiment = analyze_headlines_sentiment_advanced(df)
#       3 # Display the results
#       4 print(df_with_sentiment[['headline', 'sentiment']].head())
#
# NameError: name 'analyze_headlines_sentiment_advanced' is not defined
