# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath('../scripts'))

# %%
df = pd.read_csv('../data/raw_analyst_ratings.csv')

# %% [markdown]
# Descriptive Statistics for Textual Lengths

# %%
from analysis_functions import analyze_headline_length
print(analyze_headline_length(df))
# Out:
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64

# %% [markdown]
# Counting the Number of Articles per Publisher

# %%
from analysis_functions import count_articles_per_publisher
print(count_articles_per_publisher(df))
# Out:
# publisher
# Paul Quintaro                      228373
# Lisa Levin                         186979
# Benzinga Newsdesk                  150484
# Charles Gross                       96732
# Monica Gerson                       82380
#                                     ...
# Shazir Mucklai - Imperium Group         1
# Laura Jennings                          1
# Eric Martin                             1
# Jose Rodrigo                            1
# Jeremie Capron                          1
# Name: count, Length: 1034, dtype: int64

# %% [markdown]
# Analyzing Publication Dates for Trends

# %%
from analysis_functions import analyze_publication_dates
analyze_publication_dates(df)
# Out:
# date
# 2011-04-28 00:00:00+00:00      3
# 2011-04-29 00:00:00+00:00      2
# 2011-04-30 00:00:00+00:00      1
# 2011-05-01 00:00:00+00:00      1
# 2011-05-02 00:00:00+00:00      9
#                             ...
# 2020-06-07 00:00:00+00:00     25
# 2020-06-08 00:00:00+00:00    765
# 2020-06-09 00:00:00+00:00    803
# 2020-06-10 00:00:00+00:00    807
# 2020-06-11 00:00:00+00:00    544
# Freq: D, Length: 3333, dtype: int64

# %% [markdown]
# Perform and Plot Sentiment Analysis  for VADER and TextBlob

# %%
from sentiment_analysis import analyze_display_and_plot_sentiments
analyze_display_and_plot_sentiments(df)
# Out:
#                                                   headline  \
# 1201723  Syntel, Inc. Reports Q1 EPS of $1.11 vs $1.03 ...
# 1282616  Mid-Day Market Update: K2M Group Rises On Acqu...
# 554075   Aramchol's Failed Past Isn't Its Future; Galme...
# 1190332     60 Stocks Moving In Thursday's Mid-Day Session
# 192958   Anheuser-Busch shares are trading lower after ...
#
#         vader_sentiment_label textblob_sentiment_label
# 1201723               neutral                  neutral
# 1282616              positive                  neutral
# 554075               negative                 negative
# 1190332               neutral                  neutral
# 192958                neutral                  neutral
#
# VADER Sentiment Counts:
# vader_sentiment_label
# neutral     741194
# positive    441858
# negative    224276
# Name: count, dtype: int64
#
# TextBlob Sentiment Counts:
# textblob_sentiment_label
# neutral     934914
# positive    341178
# negative    131236
# ...

# %% [markdown]
# Pie Chart Sentiment analysis

# %%
from sentiment_analysis import pie_chart 
pie_chart(df)
# Out:
#          Unnamed: 0                                           headline  \
# 0                 0            Stocks That Hit 52-Week Highs On Friday
# 1                 1         Stocks That Hit 52-Week Highs On Wednesday
# 2                 2                      71 Biggest Movers From Friday
# 3                 3       46 Stocks Moving In Friday's Mid-Day Session
# 4                 4  B of A Securities Maintains Neutral on Agilent...
# ...             ...                                                ...
# 1407323     1413844             Top Narrow Based Indexes For August 29
# 1407324     1413845  Recap: Wednesday's Top Percentage Gainers and ...
# 1407325     1413846  UPDATE: Oppenheimer Color on China Zenix Auto ...
# 1407326     1413847  Oppenheimer Initiates China Zenix At Outperfor...
# 1407327     1413848  China Zenix Auto International Opens For Tradi...
#
#                                                        url          publisher  \
# ...

# %% [markdown]
# Time Series Analysis

# %%
from sentiment_analysis import analyze_publication_frequency
freq_df = analyze_publication_frequency(df, time_interval='D')
# Out:
# ...
# Headlines during spike periods:
#               date                                           headline
# 373697  2009-08-10  Four Winds Casino Resort Unveils New Smoke-Fre...
# 1128090 2009-08-10  Wave Q2 Revenues Rose 142% to $4.8 Million and...
# 140931  2009-08-10        Corix Acquires Fairbanks Sewer & Water Inc.
# 966433  2009-08-10  Oracle Integrates Oracle's Value Chain Plannin...
# 140930  2009-08-10     CUPE BC: Paramedics in Campbell River Rock On!
# ...            ...                                                ...
# 1217970 2020-05-01  Credit Suisse Maintains Neutral on 2U, Lowers ...
# 1217971 2020-05-01  Needham Maintains Buy on 2U, Raises Price Targ...
# 548123  2020-05-01  Shares of several oil and gas companies are tr...
# 570226  2020-05-01  Shares of several oil and gas companies are tr...
# 11      2020-05-01  Shares of several healthcare companies are tra...
#
# [319643 rows x 2 columns]

# %%
from sentiment_analysis import analyze_publication_frequency
freq_df = analyze_publication_frequency(df, time_interval='D')
# Out:
# ...
# Headlines during spike periods:
#               date                                           headline
# 373697  2009-08-10  Four Winds Casino Resort Unveils New Smoke-Fre...
# 1128090 2009-08-10  Wave Q2 Revenues Rose 142% to $4.8 Million and...
# 140931  2009-08-10        Corix Acquires Fairbanks Sewer & Water Inc.
# 966433  2009-08-10  Oracle Integrates Oracle's Value Chain Plannin...
# 140930  2009-08-10     CUPE BC: Paramedics in Campbell River Rock On!
# ...            ...                                                ...
# 1217970 2020-05-01  Credit Suisse Maintains Neutral on 2U, Lowers ...
# 1217971 2020-05-01  Needham Maintains Buy on 2U, Raises Price Targ...
# 548123  2020-05-01  Shares of several oil and gas companies are tr...
# 570226  2020-05-01  Shares of several oil and gas companies are tr...
# 11      2020-05-01  Shares of several healthcare companies are tra...
#
# [319643 rows x 2 columns]

# %%
from sentiment_analysis import perform_topic_modeling
perform_topic_modeling(df, num_topics=5, num_words=10)

# %%
from sentiment_analysis  import analyze_publisher_domains
domain_counts = analyze_publisher_domains(df)

# Display the results
print(domain_counts)
# Out:
#                    Domain  Frequency
# 0            benzinga.com       7937
# 1               gmail.com        139
# 2            andyswan.com          5
# 3          investdiva.com          2
# 4           tothetick.com          2
# 5           eosdetroit.io          1
# 6  forextraininggroup.com          1
# 7         stockmetrix.net          1
