# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.abspath('../scripts'))
from analysis_functions import analyze_headline_length,count_articles_per_publisher,analyze_publication_dates
from sentiment_analysis import analyze_sentiment 

df = pd.read_csv('../data/raw_analyst_ratings.csv')

# %% [markdown]
# Descriptive Statistics for Textual Lengths

# %%
print(analyze_headline_length(df))
# Out:
# count    1.407328e+06
# mean     7.312051e+01
# std      4.073531e+01
# min      3.000000e+00
# 25%      4.700000e+01
# 50%      6.400000e+01
# 75%      8.700000e+01
# max      5.120000e+02
# Name: headline_length, dtype: float64

# %% [markdown]
# Counting the Number of Articles per Publisher

# %%
print(count_articles_per_publisher(df))
# Out:
# publisher
# Paul Quintaro                      228373
# Lisa Levin                         186979
# Benzinga Newsdesk                  150484
# Charles Gross                       96732
# Monica Gerson                       82380
#                                     ...
# Shazir Mucklai - Imperium Group         1
# Laura Jennings                          1
# Eric Martin                             1
# Jose Rodrigo                            1
# Jeremie Capron                          1
# Name: count, Length: 1034, dtype: int64

# %% [markdown]
# Analyzing Publication Dates for Trends

# %%
analyze_publication_dates(df)
# Out:
# date
# 2011-04-28 00:00:00+00:00      3
# 2011-04-29 00:00:00+00:00      2
# 2011-04-30 00:00:00+00:00      1
# 2011-05-01 00:00:00+00:00      1
# 2011-05-02 00:00:00+00:00      9
#                             ...
# 2020-06-07 00:00:00+00:00     25
# 2020-06-08 00:00:00+00:00    765
# 2020-06-09 00:00:00+00:00    803
# 2020-06-10 00:00:00+00:00    807
# 2020-06-11 00:00:00+00:00    544
# Freq: D, Length: 3333, dtype: int64

# %%
sample_df = df.sample(frac=0.1, random_state=1)  # Use 10% of the data
sentiment_count_df = analyze_sentiment(sample_df)
print(sentiment_count_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 sample_df = df.sample(frac=0.1, random_state=1)  # Use 10% of the data
# ----> 2 sentiment_count_df = analyze_sentiment(sample_df)
#       3 print(sentiment_count_df)
#
# File c:\Users\AYUBO\Sentiment-Driven-Financial-Forecasting\scripts\sentiment_analysis.py:18, in analyze_sentiment(df, sample_size)
#      15 if 'headline' not in df.columns:
#      16     raise KeyError("The DataFrame does not contain a 'headline' column.")
# ---> 18 # Define a function to classify sentiment
#      19 def classify_sentiment(text):
#      20     analysis = TextBlob(text)
#
# File c:\Users\AYUBO\Sentiment-Driven-Financial-Forecasting\myenv\lib\site-packages\pandas\core\generic.py:5858, in NDFrame.sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5855 if weights is not None:
# ...
